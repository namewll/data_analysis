# %%
import pandas as pd

# %%
a1=pd.read_excel('./总共酒店数据.xlsx')
a1
# Out:
#                       酒店名称                                              合并后评论  \
# 0        \n乐乎酒店(北京对外经贸大学店)  福** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 1         \n京玺酒店(北京国贸SKP店)  如** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 2          \n京玺酒店(北京国贸劲松店)  b** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 3     \n优轩酒店（南宁青秀山风景区万象城店）  h** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 4          \n全季南宁火车站明秀东路酒店  四** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# ..                     ...                                                ...
# 284         \n南宁龙光那莲豪华精选酒店  c** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 285            \n广西沃顿国际大酒店  t** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 286     \n沃笙酒店(万象城南宁火车东站店)  t** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 287        \n沃笙酒店(南宁江南旗舰店)  r** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 288  \n金庆盛金钻酒店(万象城南宁火车东站店)  p** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
#
# ...

# %%
a1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   酒店名称    289 non-null    object
#  1   合并后评论   289 non-null    object
#  2   评论数量    289 non-null    int64
#  3   酒店评分    287 non-null    object
#  4   最低价格    289 non-null    object
#  5   最高价格    289 non-null    object
#  6   酒店级别    289 non-null    object
#  7   城市级别    289 non-null    object
#  8   城市      289 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 20.4+ KB

# %%
a1.describe()
# Out:
#              评论数量
# count  289.000000
# mean    21.238754
# std      2.422784
# min     18.000000
# 25%     21.000000
# 50%     21.000000
# 75%     21.000000
# max     50.000000

# %%
import re
import numpy as np
def jiu_score(x):
    m=re.findall(r'\d+\.?\d*',str(x))
    if m:
        return m[0]
    else:
        return np.nan
a1['酒店评分']=a1['酒店评分'].apply(lambda x:jiu_score(x)).astype('float')
a1
# Out:
#                       酒店名称                                              合并后评论  \
# 0        \n乐乎酒店(北京对外经贸大学店)  福** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 1         \n京玺酒店(北京国贸SKP店)  如** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 2          \n京玺酒店(北京国贸劲松店)  b** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 3     \n优轩酒店（南宁青秀山风景区万象城店）  h** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 4          \n全季南宁火车站明秀东路酒店  四** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# ..                     ...                                                ...
# 284         \n南宁龙光那莲豪华精选酒店  c** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 285            \n广西沃顿国际大酒店  t** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 286     \n沃笙酒店(万象城南宁火车东站店)  t** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 287        \n沃笙酒店(南宁江南旗舰店)  r** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 288  \n金庆盛金钻酒店(万象城南宁火车东站店)  p** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
#
# ...

# %%
def price(x):
    m=re.findall('\d+',x)
    if m:
        return m[0]
    else:
        return np.nan
a1['最低价格']=a1['最低价格'].apply(lambda x:price(x)).astype('int')

# %%
a1
# Out:
#                       酒店名称                                              合并后评论  \
# 0        \n乐乎酒店(北京对外经贸大学店)  福** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 1         \n京玺酒店(北京国贸SKP店)  如** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 2          \n京玺酒店(北京国贸劲松店)  b** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 3     \n优轩酒店（南宁青秀山风景区万象城店）  h** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 4          \n全季南宁火车站明秀东路酒店  四** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# ..                     ...                                                ...
# 284         \n南宁龙光那莲豪华精选酒店  c** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 285            \n广西沃顿国际大酒店  t** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 286     \n沃笙酒店(万象城南宁火车东站店)  t** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 287        \n沃笙酒店(南宁江南旗舰店)  r** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 288  \n金庆盛金钻酒店(万象城南宁火车东站店)  p** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
#
# ...

# %%
a1['最高价格']=a1['最高价格'].apply(lambda x:price(x)).astype('int')

# %%
a1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   酒店名称    289 non-null    object
#  1   合并后评论   289 non-null    object
#  2   评论数量    289 non-null    int64
#  3   酒店评分    287 non-null    float64
#  4   最低价格    289 non-null    int64
#  5   最高价格    289 non-null    int64
#  6   酒店级别    289 non-null    object
#  7   城市级别    289 non-null    object
#  8   城市      289 non-null    object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 20.4+ KB

# %%
a1.describe()
# Out:
#              评论数量        酒店评分         最低价格           最高价格
# count  289.000000  287.000000   289.000000     289.000000
# mean    21.238754    4.728920   491.519031    3599.740484
# std      2.422784    0.209311   395.887207   10160.670787
# min     18.000000    3.300000    74.000000     136.000000
# 25%     21.000000    4.600000   229.000000     392.000000
# 50%     21.000000    4.800000   386.000000     741.000000
# 75%     21.000000    4.900000   583.000000    2798.000000
# max     50.000000    5.000000  2976.000000  104574.000000

# %%
a1['平均价格']=(a1['最低价格']+a1['最高价格'])/2
a1
# Out:
#                       酒店名称                                              合并后评论  \
# 0        \n乐乎酒店(北京对外经贸大学店)  福** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 1         \n京玺酒店(北京国贸SKP店)  如** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 2          \n京玺酒店(北京国贸劲松店)  b** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 3     \n优轩酒店（南宁青秀山风景区万象城店）  h** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 4          \n全季南宁火车站明秀东路酒店  四** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# ..                     ...                                                ...
# 284         \n南宁龙光那莲豪华精选酒店  c** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 285            \n广西沃顿国际大酒店  t** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 286     \n沃笙酒店(万象城南宁火车东站店)  t** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 287        \n沃笙酒店(南宁江南旗舰店)  r** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
# 288  \n金庆盛金钻酒店(万象城南宁火车东站店)  p** 清洁程度:★★★★★★★★★★ 地理位置:★★★★★★★★★★ 服务体验:★★★★★...
#
# ...

# %%
def comment(x):
    text=re.sub(r'[^\u4e00-\u9fa5*:,。！]','',x)
    text=re.sub('店家回复','',text)
    return text
a1['合并后评论']=a1['合并后评论'].apply(lambda x:comment(x))

# %%
dimensions_keywords = {
    # 地理位置与交通维度：评价酒店位置便利性和交通条件
    '地理位置与交通': [
        '位置', '交通', '地铁', '车站', '机场', '公交', '步行', '距离', '附近', '周边',
        '便利', '方便', '地理位置', '位置交通', '交通便利', '交通方便', '周边交通',
        '地铁站', '公交站', '交通枢纽', '出行', '路程', '步行距离', '交通状况',
        '地铁口', '公交车站', '交通位置', '地理位置优越', '位置优越', '交通便捷',
        '偏远', '偏僻', '远', '不方便', '交通不便', '距离远', '位置偏僻', '交通拥堵'
    ],
    
    # 客房硬件条件与卫生维度：评价房间设施、卫生状况和舒适度
    '客房硬件条件与卫生': [
        '房间', '设施', '卫生', '干净', '整洁', '床', '床垫', '床品', '枕头', '被子',
        '卫生间', '浴室', '马桶', '淋浴', '隔音', '安静', '噪音', '吵', '小', '宽敞',
        '大', '装修', '硬件', '设备', '智能', 'wifi', '网络', '空调', '电视', '冰箱',
        '洗衣机', '烘干机', '房间设施', '卫生条件', '隔音效果', '硬件设施', '房间卫生',
        '宽敞明亮', '设施齐全', '设施完善', '设备先进', '干净卫生', '整洁干净', '舒适',
        '隔音不好', '噪音大', '房间小', '设施旧', '设备损坏', '不干净', '卫生差',
        '床单', '被罩', '毛巾', '浴室', '洗手间', '卫生间', '热水', '水温', '水压',
        '装修风格', '装修档次', '房间大小', '空间', '面积', '隔音效果', '安静程度'
    ],
    
    # 人员服务维度：评价酒店员工的服务态度和专业性
    '人员服务': [
        '服务', '前台', '工作人员', '员工', '态度', '热情', '周到', '贴心', '耐心', '专业',
        '经理', '保洁', '阿姨', '小姐姐', '小哥哥', '帮忙', '帮助', '解决问题', '及时',
        '响应', '客服', '服务员', '服务态度', '前台服务', '客房服务', '热情周到',
        '服务贴心', '态度友好', '响应迅速', '专业服务', '细致服务', '热情接待',
        '态度差', '服务慢', '不热情', '不专业', '不负责任', '服务态度差', '服务不到位',
        '前台接待', '客房服务', '行李服务', '咨询服务', '服务意识', '服务效率'
    ],
    
    # 餐饮与配套设施维度：评价酒店餐饮质量和其他设施
    '餐饮与配套设施': [
        '早餐', '餐饮', '餐厅', '食品', '美食', '小吃', '咖啡', '茶水', '健身房', '洗衣房',
        '停车场', '停车', '厨房', '配套', '设施', '设备', '免费', '收费', '餐饮服务',
        '餐饮设施', '配套设施', '餐厅服务', '早餐丰富', '餐饮多样', '设施齐全',
        '免费停车', '健身设施', '洗衣服务', '配套设施完善', '游泳池', 'spa', '会议室',
        '商务中心', '行政酒廊', '酒廊', '餐厅质量', '早餐质量', '餐饮质量',
        '早餐差', '餐饮不好', '设施不全', '停车难', '收费高', '设施老旧', '设施不全'
    ],
    
    # 综合性价比与整体推荐意愿：评价整体价值和推荐意向
    '综合性价比与整体推荐意愿': [
        '性价比', '价格', '价位', '便宜', '贵', '划算', '值', '推荐', '满意', '不满意',
        '体验', '入住', '整体', '综合', '再次', '下次', '还会', '再来', '整体体验',
        '入住体验', '推荐意愿', '性价比高', '性价比低', '物超所值', '值得推荐',
        '强烈推荐', '下次再来', '还会再来', '物有所值', '价格合理', '价格公道',
        '不划算', '不值', '价格贵', '性价比差', '不推荐', '不会再来', '整体评价',
        '综合评价', '推荐度', '满意度', '入住感受', '住宿体验'
    ]
}
def get_comment_score(x):
    index1=0
    index2=0
    index3=0
    index4=0
    index5=0
    for i in dimensions_keywords['地理位置与交通']:
        if i in x:
            index1+=1
            
    for i in dimensions_keywords['客房硬件条件与卫生']:
        if i in x:
            index2+=1
            
    for i in dimensions_keywords['人员服务']:
        if i in x:
            index3+=1
            
    for i in dimensions_keywords['餐饮与配套设施']:
        if i in x:
            index4+=1
            
    for i in dimensions_keywords['综合性价比与整体推荐意愿']:
        if i in x:
            index5+=1
    return [index1,index2,index3,index4,index5]
    
a1['地理位置与交通评分']=a1['合并后评论'].apply(lambda x:get_comment_score(x)[0])
a1['客房硬件条件与卫生']=a1['合并后评论'].apply(lambda x:get_comment_score(x)[1])
a1['人员服务']=a1['合并后评论'].apply(lambda x:get_comment_score(x)[2])
a1['餐饮与配套设施']=a1['合并后评论'].apply(lambda x:get_comment_score(x)[3])
a1['综合性价比与整体推荐意愿']=a1['合并后评论'].apply(lambda x:get_comment_score(x)[4])

# %%
a1
# Out:
#                       酒店名称                                              合并后评论  \
# 0        \n乐乎酒店(北京对外经贸大学店)  福**清洁程度:地理位置:服务体验:性价比:房间干净舒适,床单被罩崭新如初房间干净舒适床单被...
# 1         \n京玺酒店(北京国贸SKP店)  如**清洁程度:地理位置:服务体验:性价比:房间很小,说房间太小了离地铁算比较近我们都有考虑...
# 2          \n京玺酒店(北京国贸劲松店)  **清洁程度:地理位置:服务体验:性价比:前台小姐姐很好,真的很温馨前台小姐姐很好温柔又有耐...
# 3     \n优轩酒店（南宁青秀山风景区万象城店）  **清洁程度:地理位置:服务体验:性价比:房间非常宽敞,干净,床品舒适这家酒店真的太棒了从入...
# 4          \n全季南宁火车站明秀东路酒店  四**清洁程度:地理位置:服务体验:性价比:非常下头,总之这种服务态度带这一家老小选择了离地...
# ..                     ...                                                ...
# 284         \n南宁龙光那莲豪华精选酒店  **清洁程度:地理位置:服务体验:性价比:房间采光超棒,离办事的地方也近来南宁出差订的这家酒...
# 285            \n广西沃顿国际大酒店  **清洁程度:地理位置:服务体验:性价比:普通大床房,如图,没有大床房了首先我定的是湖景大床...
# 286     \n沃笙酒店(万象城南宁火车东站店)  **清洁程度:地理位置:服务体验:性价比:酒店的前台服务值得肯定本次傍晚入住的体验有亮点也存...
# 287        \n沃笙酒店(南宁江南旗舰店)  **清洁程度:地理位置:服务体验:性价比:干净整洁,非常贴心酒店位置交通靠近机场非常方便房间...
# 288  \n金庆盛金钻酒店(万象城南宁火车东站店)  **清洁程度:地理位置:服务体验:性价比:老酒店了,是酒店需要装修了老酒店了有股怪味就是那种...
#
# ...

# %% [markdown]
# ###

# %%
a1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   酒店名称          289 non-null    object
#  1   合并后评论         289 non-null    object
#  2   评论数量          289 non-null    int64
#  3   酒店评分          287 non-null    float64
#  4   最低价格          289 non-null    int64
#  5   最高价格          289 non-null    int64
#  6   酒店级别          289 non-null    object
#  7   城市级别          289 non-null    object
#  8   城市            289 non-null    object
#  9   平均价格          289 non-null    float64
#  10  地理位置与交通评分     289 non-null    int64
#  11  客房硬件条件与卫生     289 non-null    int64
#  12  人员服务          289 non-null    int64
#  13  餐饮与配套设施       289 non-null    int64
#  14  综合性价比与整体推荐意愿  289 non-null    int64
# dtypes: float64(2), int64(8), object(5)
# memory usage: 34.0+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %%
x=['地理位置与交通','客房硬件条件与卫生','人员服务','餐饮与配套设施','综合性价比与整体推荐意愿']
y=[a1['地理位置与交通评分'].mean(),a1['客房硬件条件与卫生'].mean(),a1['人员服务'].mean(),a1['餐饮与配套设施'].mean(),a1['综合性价比与整体推荐意愿'].mean()]

# %%
plt.figure(figsize=(10,6))
plt.title('酒店各维度平均得分',fontsize=14)
plt.bar(x,y,color=['red','blue','green','yellow','black'],alpha=0.5)
# plt.bar(x,y,color=['#FF9999', '#66B2FF', '#99FF99', '#FFD700', '#DDA0DD'],alpha=0.5)
plt.xlabel('维度')
plt.ylabel('平均分')
plt.show()

# %%
a1['满意总分']=a1['地理位置与交通评分']+a1['客房硬件条件与卫生']+a1['人员服务']+a1['餐饮与配套设施']+a1['综合性价比与整体推荐意愿']

# %%
plt.figure(figsize=(10,6))
plt.hist(a1['满意总分'],bins=15,color='lightblue',edgecolor='black')
mean_score=a1['满意总分'].mean()
plt.axvline(mean_score,color='red',linestyle='--',label=f"平均分：{mean_score:.2f}")
# plt.axhline(40,color='blue',linestyle='--')
plt.xlabel('满意总分',fontsize=15)
plt.ylabel('酒店数量',fontsize=15)
plt.legend()
plt.show()
